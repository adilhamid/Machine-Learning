# %%
# Code for Problem number 8 - Momentum


import numpy as np
import matplotlib.pyplot as plt
import math

def Get_Error_Val(w):
    return ((w - 2)*(w - 4.5)*(w - 5)*(w - 5.5))

def Get_Derivate_Val(w):
    return (4 * pow(w, 3) - 51 * pow(w, 2) + 209.5*w - 273.25)

def plotFuntion(weights):
    t1 = np.arange(0.0, 8.0, 0.01)
    t2 = np.array(weights)
    
    plt.figure(1)
    plt.subplot(111)
    plt.xlabel('w')
    plt.ylabel('E(w)')
    plt.plot(t1, Get_Error_Val(t1),t2, Get_Error_Val(t2),'ro' )

    plt.show()

def Get_Gradient_Descent(learning_rate, initial_weights, globalMinima):
    counter =0;
    
    for weight in initial_weights:
        counter =0;
        momentum = 0.1       
        
        print 'For Initial Weight: ', weight
       
        
        while (Get_Error_Val(weight) > globalMinima and momentum <=0.9):
            print 'Momentum' , momentum
            flagInf = False
            oldDeltaVal = 0
            newVal = 0.0
            newWeight = weight
           
            weightList = []
            weightList.append(weight)
            presentVal = Get_Error_Val(weight)
            
            counter =0
            
            while True:
                if(counter>0):
                    presentVal = newVal
                    oldDeltaVal = newDelta
                
                newDelta = learning_rate * Get_Derivate_Val(newWeight) + momentum * oldDeltaVal
                newWeight = newWeight - newDelta
                
                if (-1.9 <= newWeight <= 8.5 ):
                    weightList.append(newWeight)
                
                newVal = Get_Error_Val(newWeight)

                counter = counter + 1
                
                if math.isinf(presentVal) or presentVal > 200:
                    flagInf = True
                    break
                if(abs(newVal-presentVal) < 0.001):
                    break
                #print counter, newWeight , presentVal
            
            if not flagInf:
                print 'Total Number of Iterations needed to Converge is: ', counter
            else:
                print 'The Convergence is not happening'
            print 
            plotFuntion(weightList)
            momentum = momentum + 0.1
        
        print '--------------------------------------------------------------------------------------------'
        
        print
        

weights = [ 1, 2, 3, 4.5, 4.75, 6, 8]
learningRate = 0.05
globalminima = -8.12461
Get_Gradient_Descent(learningRate, weights, globalminima)
# Out:
# For Initial Weight:  1
# Momentum 0.1
# Total Number of Iterations needed to Converge is:  4
# Momentum 0.2
# Total Number of Iterations needed to Converge is:  5
# Momentum 0.3
# Total Number of Iterations needed to Converge is:  15
# Momentum 0.4
# Total Number of Iterations needed to Converge is:  14
# Momentum 0.5
# Total Number of Iterations needed to Converge is:  32
# Momentum 0.6
# The Convergence is not happening
# Momentum 0.7
# The Convergence is not happening
# Momentum 0.8
# The Convergence is not happening
# Momentum 0.9
# The Convergence is not happening
# --------------------------------------------------------------------------------------------
#
# For Initial Weight:  2
# Momentum 0.1
# Total Number of Iterations needed to Converge is:  7
# Momentum 0.2
# Total Number of Iterations needed to Converge is:  7
# Momentum 0.3
# Total Number of Iterations needed to Converge is:  10
# Momentum 0.4
# Total Number of Iterations needed to Converge is:  12
# Momentum 0.5
# ...

# %% [markdown]
# Observations:
#
# 1) In case of weight 6, the addition of the momentum really helped when it was more than 0.3. This happened because, when  we sarted decreasing from E(6) we were not stuck at the local minima as in case of when we were only using the eta(learning rate.
# Thus the additiong of the momentum helped when the learner was getting stuck at local minima.
#
# 2) In case of weights, w=8, w=6 with momentum <0.3 didn't help much as it didn't decrease the error such that it could lead to the global minima. Also it ruined the results for some weights when the momentum was quite high leading to some other minima.
#
# 3) When eta = 0.005, it will only help in cases where the derivate leads to the global minima. since the effect of momentum is decreased by using small learning rate, so there will be cases where our function will get stuck in the local minima.
